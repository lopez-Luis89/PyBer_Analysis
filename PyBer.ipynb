# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statistics
from matplotlib.ticker import MultipleLocator

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, marker = "*", color = "red", linewidth = 2, label = "Boston")
plt.xlabel("Date")
plt.ylabel("Total Fare($)")
#Setting Limits
plt.ylim(0,45)
#Crearint A Title
plt.title("PyBer Fare By Month")
#Adding A Legend
plt.legend()
#Adding Grid
plt.grid()
#Partition the graph using indexing
plt.xlim(0,5)
#changing the pixles
plt.figure(figsize = (20,10))
plt.show()

# %%
fig, ax=plt.subplots()
ax.plot(x_axis,y_axis)

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.bar(x_axis, y_axis, color ="red", label = "Boston")
plt.xlabel("Months")
plt.ylabel("Fare($)")
plt.title("Boston Fare By Month")
plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.barh(x_axis,y_axis, color = "green", label = "Boston")
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color = 'black', label = 'New York')
plt.legend()

# %%
fig, ax = plt.subplots()
ax.barh(x_axis,y_axis, color = 'magenta', label = 'New York')
plt.gca().invert_yaxis()
plt.ylabel('Month')
plt.xlabel('Fare($)')
plt.legend()
plt.title('Fare By Month New York')

# %% [markdown]
# ## 5.1.7 scatter plots

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.plot(x_axis, y_axis, 'o')

# %%
plt.scatter(x_axis, y_axis, s = y_axis)
plt.xlabel('Date')
plt.ylabel('Fare')
plt.title('Fare By Month')
# Out:
# Text(0.5, 1.0, 'Fare By Month')

# %%
plt.scatter( y_axis,x_axis, s = [i*3 for i in y_axis], c = 'b', alpha = .2, edgecolors = 'black', norm = 1)
plt.gca().invert_yaxis()

# %% [markdown]
# # 5.1.8 Pie Charts

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]


explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)

plt.subplots(figsize = (8,8))
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%', colors = colors)

plt.show()

# %% [markdown]
# # Using object oriented

# %%
fig, ax = plt.subplots()

ax.pie(y_axis,labels=x_axis)
plt.show()

# %% [markdown]
# # 5.1. 9 Extras

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
std = statistics.stdev(y_axis)
std
# Out:
# 11.208367917035753

# %%
plt.errorbar(x_axis,y_axis, yerr = std, capsize = 3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# # Object oriented

# %%
fig, ax = plt.subplots()
ax.errorbar(x_axis, y_axis, yerr = std, capsize = 4)
plt.show()

# %%
fig, ax= plt.subplots()
ax.bar(x_axis, y_axis, yerr = std , capsize =4 )
plt.show()

# %%
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step = 5))
plt.gca().invert_yaxis()

# %%
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
